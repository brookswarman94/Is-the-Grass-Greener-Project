# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import pandas as pd
import numpy as np
import requests
import time
import csv
import time
from datetime import datetime

# %%
#****************SEATTLE DATA********************

# %%
# crime data
#seattle_df = pd.read_csv("crime_data_seattle.csv")
#seattle_df.head()

#phoenix_df = pd.read_csv("crime-data_phoenix.csv")
#phoenix_df.head()

#chicago_df = pd.read_csv("Crimes_data_chicago.csv")
#chicago_df.head()

# %%
# crime data SEATTLE
seattle_df = pd.read_csv("crime_data_seattle.csv")
seattle_df.head()
# Out:
#     Report Number Occurred Date  Occurred Time Reported Date  Reported Time  \
# 0   2017000097473    03/19/2017         1909.0    03/19/2017         1909.0
# 1   2017000097475    03/19/2017         1909.0    03/19/2017         1909.0
# 2  20080000465209    12/13/1908         2114.0    12/13/2008         2114.0
# 3  20100000202011    06/15/1964            0.0    06/15/2010         1031.0
# 4   2012000023437    01/01/1973            0.0    01/25/2012         1048.0
#
#            Crime Subcategory Primary Offense Description Precinct Sector Beat  \
# 0                   TRESPASS                    TRESPASS     WEST      M   M3
# 1                        DUI                  DUI-LIQUOR    NORTH      L   L2
# 2                        DUI                  DUI-LIQUOR     EAST      G   G2
# 3  FAMILY OFFENSE-NONVIOLENT                 CHILD-OTHER     WEST      Q   Q2
# 4          SEX OFFENSE-OTHER                SEXOFF-OTHER    NORTH      N   N2
#
#                Neighborhood
# 0       DOWNTOWN COMMERCIAL
# 1                 NORTHGATE
# 2  CENTRAL AREA/SQUIRE PARK
# 3                QUEEN ANNE
# 4                 NORTHGATE

# %%
#SEATTLE
#select columns from data base to merge
new_seattle_df = seattle_df[['Occurred Date', 'Crime Subcategory']]
#new_seattle_df.head()

new2_seattle_df = seattle_df[['Occurred Date', 'Crime Subcategory']]
new_seattle_df["Year"]=new_seattle_df["Occurred Date"].str[-4:]
new_seattle_df.head()

#new_seattle_df.describe()

new_seattle_df.groupby(['Year']).count().reset_index()
# Out:
# C:\Users\niche\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#     Year  Occurred Date  Crime Subcategory
# 0   1908              1                  1
# 1   1964              1                  1
# 2   1973              1                  1
# 3   1974              1                  1
# 4   1975              2                  2
# 5   1976              2                  2
# 6   1977              1                  1
# 7   1978              1                  1
# 8   1979              2                  2
# 9   1980              2                  2
# 10  1981              2                  2
# 11  1985              2                  2
# 12  1986              1                  1
# 13  1987              1                  1
# 14  1988              1                  1
# 15  1989              1                  1
# 16  1990              2                  2
# 17  1991              2                  2
# 18  1993              5                  5
# 19  1994              2                  2
# 20  1995              6                  6
# 21  1996              4                  4
# 22  1997              5                  5
# 23  1998             20                 20
# 24  1999              8                  8
# 25  2000             40                 40
# 26  2001             53                 53
# 27  2002             17                 17
# 28  2003             28                 28
# 29  2004             41                 41
# 30  2005             49                 49
# 31  2006             99                 99
# 32  2007            627                627
# 33  2008          42792              42606
# 34  2009          45055              45013
# 35  2010          43350              43320
# 36  2011          41296              41292
# 37  2012          41004              41004
# 38  2013          45548              45548
# 39  2014          49314              49314
# 40  2015          47687              47687
# 41  2016          49201              49201
# 42  2017          50301              50301
# 43  2018          41362              41362

# %%
#*******SEATTLE*******Print last 4 years = new_seattle4years_df

seattle4years_df = new_seattle_df.groupby(['Year']).count().reset_index()
new_seattle4years_df = seattle4years_df.iloc[[40,41,42,43],[0,1]]
new_seattle4years_df

#new_seattle4years_df = seattle4years_df.iloc[1:40,43]
#new_seattle4years_df

#data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
#df_SN7577.iloc[1:4]
# Out:
#     Year  Occurred Date
# 40  2015          47687
# 41  2016          49201
# 42  2017          50301
# 43  2018          41362

# %%
#***********PLot Info SEATTLE-need 4 years**********
new_seattle4years_df.rename(columns={'Occurred Date':'Total Crimes S'}, inplace=True)
new_seattle4years_df

#gapminder.rename(columns={'pop':'population'}, inplace=True)
# Out:
#     Year  Total Crimes S
# 40  2015           47687
# 41  2016           49201
# 42  2017           50301
# 43  2018           41362

# %%
#****************PHOENIX DATA********************

# %%
phoenix_df = pd.read_csv("crime-data_phoenix.csv")
#phoenix_df.head()

new_phoenix_df = phoenix_df[['OCCURRED ON','UCR CRIME CATEGORY']]
new_phoenix_df["Year"]=new_phoenix_df["OCCURRED ON"].str[6:10]
#new_phoenix_df.head()

phoenix4years_df = new_phoenix_df.groupby(['Year']).count().reset_index()
phoenix4years_df
# Out:
# C:\Users\niche\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\niche\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#    Year  OCCURRED ON  UCR CRIME CATEGORY
# 0  2015        10121               10121
# 1  2016        63182               63182
# 2  2017        65950               65950
# 3  2018        51148               51148

# %%
#***********PLot Info SEATTLE-need 4 years**********
new_phoenix4years_df = phoenix4years_df.iloc[[0,1,2,3],[0,1]]
new_phoenix4years_df.rename(columns={'OCCURRED ON':'Total Crimes P'}, inplace=True)
new_phoenix4years_df

#data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
# Out:
#    Year  Total Crimes P
# 0  2015           10121
# 1  2016           63182
# 2  2017           65950
# 3  2018           51148

# %%
#******DATA__GRAPH for CRIME BY CITY*****
# Merge file
Cities_Crime_df = pd.merge(new_seattle4years_df, new_phoenix4years_df)
Cities_Crime_df
# Out:
#    Year  Total Crimes S  Total Crimes P
# 0  2015           47687           10121
# 1  2016           49201           63182
# 2  2017           50301           65950
# 3  2018           41362           51148

# %%
#******GRAPH for CRIME BY CITY*****
# gca stands for 'get current axis'
ax = plt.gca()

Cities_Crime_df.plot(kind='line',x='Year',y='Total Crimes S',ax=ax)
Cities_Crime_df.plot(kind='line',x='Year',y='Total Crimes P', color='red', ax=ax)

# naming the x axis
#plt.xlabel('Date')
# naming the y axis
plt.ylabel('Number of Crimes')
# giving a title  
plt.title('Crime Total Per City') 
# Turn on the minor TICKS, which are required for the minor GRID
##plt.minorticks_on()




# Customize the major grid
##plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
##plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')


plt.show()

#df.plot(kind='line',x='name',y='num_children',ax=ax)
#df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax)
#plt.show()

# %%
pop_units=100000
pop_seattle =704358/pop_units
pop_phoenix =1620000/pop_units
pop_chicago =2700000/pop_units



#pop_capita_seattle_df=Cities_Crime_df['Total Crimes S']/pop_seattle
#pop_capita_seattle_df




Cities_Crime_df["Phoenix Per Capita"] = Cities_Crime_df["Total Crimes P"]/pop_phoenix
Cities_Crime_df["Seattle Per Capita"] = Cities_Crime_df["Total Crimes S"]/pop_seattle
Cities_Crime_df


#pop_capita_phoenix_df=Cities_Crime_df['Total Crimes p']/pop_phoenix
#pop_capita_phoenix_df


#Cities_Crime_df['']

#final_cities_data_df =



#Cities_Crime_df.plot(kind='line',x='Year',y='Total Crimes S',ax=ax)
#Cities_Crime_df.plot(kind='line',x='Year',y='Total Crimes P', color='red', ax=ax)


#     df = df ['1'] * 10000

# naming the x axis
#plt.xlabel('Date')
# naming the y axis
##plt.ylabel('Number of Crimes')
# giving a title  
##plt.title('Crime Total Per City') 
# Turn on the minor TICKS, which are required for the minor GRID
##plt.minorticks_on()


##ax = plt.gca()

##Cities_Crime_df.plot(kind='line',x='Year',y='Total Crimes S',ax=ax)
##Cities_Crime_df.plot(kind='line',x='Year',y='Total Crimes P', color='red', ax=ax)

# naming the x axis
#plt.xlabel('Date')
# naming the y axis
##plt.ylabel('Number of Crimes')
# giving a title  
##plt.title('Crime Total Per City') 
# Turn on the minor TICKS, which are required for the minor GRID
##plt.minorticks_on()
# Out:
#    Year  Total Crimes S  Total Crimes P  Phoenix Per Capita  \
# 0  2015           47687           10121          624.753086
# 1  2016           49201           63182         3900.123457
# 2  2017           50301           65950         4070.987654
# 3  2018           41362           51148         3157.283951
#
#    Seattle Per Capita
# 0         6770.278750
# 1         6985.226263
# 2         7141.396846
# 3         5872.297894

# %%
#import Chicago csv
chicago_df=pd.read_csv('Chicago_Annual_Crime.csv')
chicago_df

#join dataframe
final_df=pd.concat([Cities_Crime_df,chicago_df], axis=1)
final_df
# Out:
#    Year  Total Crimes S  Total Crimes P  Phoenix Per Capita  \
# 0  2015           47687           10121          624.753086
# 1  2016           49201           63182         3900.123457
# 2  2017           50301           65950         4070.987654
# 3  2018           41362           51148         3157.283951
#
#    Seattle Per Capita  Year  Crimes  Per Capita (100K)
# 0         6770.278750  2015  263909        9774.407407
# 1         6985.226263  2016  268775        9954.629630
# 2         7141.396846  2017  267730        9915.925926
# 3         5872.297894  2018  212819        7882.185185

# %%
final_df = final_df[["Year", "Phoenix Per Capita", "Seattle Per Capita", "Per Capita (100K)"]]
final_df
# Out:
#    Year  Year  Phoenix Per Capita  Seattle Per Capita  Per Capita (100K)
# 0  2015  2015          624.753086         6770.278750        9774.407407
# 1  2016  2016         3900.123457         6985.226263        9954.629630
# 2  2017  2017         4070.987654         7141.396846        9915.925926
# 3  2018  2018         3157.283951         5872.297894        7882.185185

# %%
final_df.rename(index=str, columns={"Per Capita (100K)":"Chicago Per Capita"}, inplace=True)
final_df
# Out:
# C:\Users\niche\Anaconda3\lib\site-packages\pandas\core\frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#    Year  Year  Phoenix Per Capita  Seattle Per Capita  Chicago Per Capita
# 0  2015  2015          624.753086         6770.278750         9774.407407
# 1  2016  2016         3900.123457         6985.226263         9954.629630
# 2  2017  2017         4070.987654         7141.396846         9915.925926
# 3  2018  2018         3157.283951         5872.297894         7882.185185

# %%
Year = [2015, 2016, 2017, 2018]

#final_df.plot(kind='line',x= Year, y='Phoenix Per Capita', color='yellow', ax=ax)
#final_df.plot(kind='line',x= Year,y='Seattle Per Capita', color='red', ax=ax)
#final_df.plot(kind='line',x= Year,y='Chicago Per Capita', color='blue', ax=ax)

phoenix, = plt.plot(Year, final_df["Phoenix Per Capita"], color="Red", label="Phoenix")
seattle, = plt.plot(Year, final_df["Seattle Per Capita"], color="Blue", label="Seattle")
chicago, = plt.plot(Year, final_df["Chicago Per Capita"], color="Yellow", label="Chicago")

# naming the x axis
plt.xlabel('Year')
# naming the y axis
plt.ylabel('Number of Crimes')
# giving a title  
plt.title('Annual Crime Total Per City Per Capita (100K)') 
# Turn on the minor TICKS, which are required for the minor GRID
##plt.minorticks_on()
plt.legend(handles=[phoenix, chicago, seattle], loc="best")
plt.show()

# %%
#*******GRAPH for per capita-bar graph***************
pop_units=100000
pop_seattle =704358/pop_units
pop_phoenix =1620000/pop_units
pop_chicago =2700000/pop_units


avg_crime_yr_seattle = Cities_Crime_df.loc[:,"Total Crimes S"].mean()
#avg_crime_yr_seattle 
per_cap_seattle = avg_crime_yr_seattle/pop_seattle
#per_cap_seattle

avg_crime_yr_phoenix=Cities_Crime_df.loc[:,"Total Crimes P"].mean()
#avg_crime_yr_phoenix
per_cap_phoenix = avg_crime_yr_seattle/pop_phoenix
#per_cap_phoenix









#fig = plt.gcf()
#plotly_fig = tls.mpl_to_plotly(fig)
#py.iplot(plotly_fig, filename='mpl-basic-bar')

#avg_crime_yr_chicago



#df.groupby('state')['name'].nunique().plot(kind='bar')
#plt.show()

# %%
#***********CHICAGO************************

# %%
chicago_df = pd.read_csv("Crimes_data_chicago.csv")
chicago_df.tail()
# Out:
#               ID Case Number             Date                   Block  IUCR  \
# 1048570  9528062    HX182386  3/12/2014 18:45      081XX S DREXEL AVE   320
# 1048571  9528063    HX182431  3/12/2014 17:30     075XX S SANGAMON ST  2820
# 1048572  9528064    HX182363   3/12/2014 8:30      080XX S WABASH AVE   560
# 1048573  9528067    HX182438  1/30/2014 19:00  056XX S UNIVERSITY AVE  1220
# 1048574  9528069    HX182342  3/12/2014 18:02     076XX S OGLESBY AVE  1310
#
#                Primary Type                 Description Location Description  \
# 1048570             ROBBERY       STRONGARM - NO WEAPON            APARTMENT
# 1048571       OTHER OFFENSE            TELEPHONE THREAT            RESIDENCE
# 1048572             ASSAULT                      SIMPLE            APARTMENT
# 1048573  DECEPTIVE PRACTICE  THEFT OF LOST/MISLAID PROP                OTHER
# 1048574     CRIMINAL DAMAGE                 TO PROPERTY            RESIDENCE
#
#          Arrest  Domestic              ...                Ward  \
# 1048570   False     False              ...                 8.0
# 1048571   False      True              ...                17.0
# 1048572   False     False              ...                 6.0
# 1048573   False     False              ...                 5.0
# 1048574   False     False              ...                 7.0
#
#          Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 1048570            44.0         3     1183652.0    1851166.0  2014
# 1048571            71.0        26     1171284.0    1854752.0  2014
# 1048572            44.0       08A     1178107.0    1851694.0  2014
# 1048573            41.0        11     1184746.0    1867759.0  2014
# 1048574            43.0        14     1193195.0    1854763.0  2014
#
#             Updated On   Latitude  Longitude                       Location
# 1048570  2/4/2016 6:33  41.746785 -87.602625  (41.746784577, -87.602624733)
# 1048571  2/4/2016 6:33  41.756904 -87.647839  (41.756904307, -87.647839347)
# 1048572  2/4/2016 6:33  41.748361 -87.622927  (41.748360892, -87.622926885)
# 1048573  2/4/2016 6:33  41.792292 -87.598096  (41.792291742, -87.598096335)
# 1048574  2/4/2016 6:33  41.756427 -87.567540   (41.756427337, -87.56754004)
#
# [5 rows x 22 columns]

# %%
# select columns from data base to merge
# new_seattle_df = seattle_df[['Occurred Date', 'Crime Subcategory']]
# new_seattle_df.head()

# new2_seattle_df = seattle_df[['Occurred Date', 'Crime Subcategory']]
# new_seattle_df["Year"]=new_seattle_df["Occurred Date"].str[-4:]
# new_seattle_df.head()

# new_seattle_df.describe()

# new_phoenix_df = phoenix_df[['OCCURRED ON','UCR CRIME CATEGORY']]
# new_phoenix_df["Year"]=new_phoenix_df["OCCURRED ON"].str[6:10]
# new_phoenix_df.head()

new_chicago_df = chicago_df[['Date','Primary Type']]
new_chicago_df['Date'] = pd.to_datetime(new_chicago_df['Date'], errors='coerce')
new_chicago_df["Year"] = new_chicago_df["Date"].dt.year
new_chicago_df["Month"] = new_chicago_df["Date"].dt.month
new_chicago_df["Day"] = new_chicago_df["Date"].dt.day
# new_phoenix_df["Year"] = new_chicago_df["OCCURRED ON"].str[6:10]
# new_chicago_df["date]][0:4]

# yr_01 = new_chicago_df[new_chicago_df["Date"] == "2001"]
new_chicago_df.head(5)
# Out:
# C:\Users\niche\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\niche\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\niche\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\niche\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  Date   Primary Type  Year  Month  Day
# 0 2015-03-18 19:44:00        BATTERY  2015      3   18
# 1 2015-03-18 23:00:00  OTHER OFFENSE  2015      3   18
# 2 2015-03-18 22:45:00        BATTERY  2015      3   18
# 3 2015-03-18 22:30:00        BATTERY  2015      3   18
# 4 2015-03-18 21:00:00        ROBBERY  2015      3   18

# %%
#new_chicago_df = pd.DataFrame(pd.date_range('20000101', periods=150000, freq='H'), columns=['Date'])

#df = pd.DataFrame(pd.date_range('20000101', periods=150000, freq='H'), columns=['Date'])
#new_chicago_df.head(5)
# Out:
#                  Date
# 0 2000-01-01 00:00:00
# 1 2000-01-01 01:00:00
# 2 2000-01-01 02:00:00
# 3 2000-01-01 03:00:00
# 4 2000-01-01 04:00:00

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df

new_chicago_df['Year'] = df['Date'].dt.year
dnew_chicago_df['Month'] = df['Date'].dt.month
dnew_chicago_df['Day'] = df['Date'].dt.day
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-829ea393302a> in <module>()
# ----> 1 df['Year'] = df['Date'].dt.year
#       2 df['Month'] = df['Date'].dt.month
#       3 df['Day'] = df['Date'].dt.day
#       4 df
#       5
#
# NameError: name 'df' is not defined
